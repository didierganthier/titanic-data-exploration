# %%
import seaborn as sns
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
model1 = smf.logit(formula='survived ~ 1', data=titanic).fit();
model1.params
# Out:
# Optimization terminated successfully.
#          Current function value: 0.665912
#          Iterations 4
# Intercept   -0.473288
# dtype: float64

# %%
cross_tab = pd.DataFrame({
    'count': titanic['survived'].value_counts(),
    'percentage': titanic['survived'].value_counts(normalize=True)
    })

round(cross_tab,2)
# Out:
#           count  percentage
# survived
# 0           549        0.62
# 1           342        0.38

# %%
model3 = smf.logit(formula='survived ~ fare', data=titanic).fit()
model3.params
# Out:
# Optimization terminated successfully.
#          Current function value: 0.627143
#          Iterations 6
# Intercept   -0.941330
# fare         0.015197
# dtype: float64

# %%
model2 = smf.logit(formula='survived ~ C(pclass)', data=titanic).fit()
model2.params
# Out:
# Optimization terminated successfully.
#          Current function value: 0.607805
#          Iterations 5
# Intercept         0.530628
# C(pclass)[T.2]   -0.639431
# C(pclass)[T.3]   -1.670399
# dtype: float64

# %%
model4 = smf.logit(formula='survived ~ fare + C(sex) + age', data=titanic).fit()
model4.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.501450
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               survived   No. Observations:                  714
# Model:                          Logit   Df Residuals:                      710
# Method:                           MLE   Df Model:                            3
# Date:                Tue, 28 Oct 2025   Pseudo R-squ.:                  0.2576
# Time:                        14:02:52   Log-Likelihood:                -358.04
# converged:                       True   LL-Null:                       -482.26
# Covariance Type:            nonrobust   LLR p-value:                 1.419e-53
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          0.9348      0.239      3.910      0.000       0.466       1.403
# C(sex)[T.male]    -2.3476      0.190    -12.359      0.000      -2.720      -1.975
# fare               0.0128      0.003      4.738      0.000       0.007       0.018
# age               -0.0106      0.006     -1.627      0.104      -0.023       0.002
# ==================================================================================
# """

# %%
mpg = sns.load_dataset('mpg').dropna().drop(columns=['origin', 'name', 'displacement'])
mpg.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_fdbaf_row0_col0, #T_fdbaf_row1_col1, #T_fdbaf_row2_col2, #T_fdbaf_row3_col3, #T_fdbaf_row4_col4, #T_fdbaf_row5_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_fdbaf_row0_col1, #T_fdbaf_row0_col2, #T_fdbaf_row0_col3, #T_fdbaf_row2_col4, #T_fdbaf_row2_col5, #T_fdbaf_row3_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_fdbaf_row0_col4 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_fdbaf_row0_col5 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_fdbaf_row1_col0, #T_fdbaf_row2_col0 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_fdbaf_row1_col2, #T_fdbaf_row2_col1 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_fdbaf_row1_col3, #T_fdbaf_row3_col1 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_fdbaf_row1_col4 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_fdbaf_row1_col5, #T_fdbaf_row4_col2 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_fdbaf_row2_col3 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_fdbaf_row3_col2 {
#   background-color: #cf453c;
#   color: #f1f1f1;
# }
# #T_fdbaf_row3_col4 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_fdbaf_row3_col5 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_fdbaf_row4_col0 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_fdbaf_row4_col1 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_fdbaf_row4_col3 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_fdbaf_row4_col5 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_fdbaf_row5_col0 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_fdbaf_row5_col1 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_fdbaf_row5_col2 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_fdbaf_row5_col3 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_fdbaf_row5_col4 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# </style>
# <table id="T_fdbaf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fdbaf_level0_col0" class="col_heading level0 col0" >mpg</th>
#       <th id="T_fdbaf_level0_col1" class="col_heading level0 col1" >cylinders</th>
#       <th id="T_fdbaf_level0_col2" class="col_heading level0 col2" >horsepower</th>
#       <th id="T_fdbaf_level0_col3" class="col_heading level0 col3" >weight</th>
#       <th id="T_fdbaf_level0_col4" class="col_heading level0 col4" >acceleration</th>
#       <th id="T_fdbaf_level0_col5" class="col_heading level0 col5" >model_year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fdbaf_level0_row0" class="row_heading level0 row0" >mpg</th>
#       <td id="T_fdbaf_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_fdbaf_row0_col1" class="data row0 col1" >-0.777618</td>
#       <td id="T_fdbaf_row0_col2" class="data row0 col2" >-0.778427</td>
#       <td id="T_fdbaf_row0_col3" class="data row0 col3" >-0.832244</td>
#       <td id="T_fdbaf_row0_col4" class="data row0 col4" >0.423329</td>
#       <td id="T_fdbaf_row0_col5" class="data row0 col5" >0.580541</td>
#     </tr>
#     <tr>
#       <th id="T_fdbaf_level0_row1" class="row_heading level0 row1" >cylinders</th>
#       <td id="T_fdbaf_row1_col0" class="data row1 col0" >-0.777618</td>
#       <td id="T_fdbaf_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_fdbaf_row1_col2" class="data row1 col2" >0.842983</td>
#       <td id="T_fdbaf_row1_col3" class="data row1 col3" >0.897527</td>
#       <td id="T_fdbaf_row1_col4" class="data row1 col4" >-0.504683</td>
#       <td id="T_fdbaf_row1_col5" class="data row1 col5" >-0.345647</td>
#     </tr>
#     <tr>
#       <th id="T_fdbaf_level0_row2" class="row_heading level0 row2" >horsepower</th>
#       <td id="T_fdbaf_row2_col0" class="data row2 col0" >-0.778427</td>
#       <td id="T_fdbaf_row2_col1" class="data row2 col1" >0.842983</td>
#       <td id="T_fdbaf_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_fdbaf_row2_col3" class="data row2 col3" >0.864538</td>
#       <td id="T_fdbaf_row2_col4" class="data row2 col4" >-0.689196</td>
#       <td id="T_fdbaf_row2_col5" class="data row2 col5" >-0.416361</td>
#     </tr>
#     <tr>
#       <th id="T_fdbaf_level0_row3" class="row_heading level0 row3" >weight</th>
#       <td id="T_fdbaf_row3_col0" class="data row3 col0" >-0.832244</td>
#       <td id="T_fdbaf_row3_col1" class="data row3 col1" >0.897527</td>
#       <td id="T_fdbaf_row3_col2" class="data row3 col2" >0.864538</td>
#       <td id="T_fdbaf_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_fdbaf_row3_col4" class="data row3 col4" >-0.416839</td>
#       <td id="T_fdbaf_row3_col5" class="data row3 col5" >-0.309120</td>
#     </tr>
#     <tr>
#       <th id="T_fdbaf_level0_row4" class="row_heading level0 row4" >acceleration</th>
#       <td id="T_fdbaf_row4_col0" class="data row4 col0" >0.423329</td>
#       <td id="T_fdbaf_row4_col1" class="data row4 col1" >-0.504683</td>
#       <td id="T_fdbaf_row4_col2" class="data row4 col2" >-0.689196</td>
#       <td id="T_fdbaf_row4_col3" class="data row4 col3" >-0.416839</td>
#       <td id="T_fdbaf_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_fdbaf_row4_col5" class="data row4 col5" >0.290316</td>
#     </tr>
#     <tr>
#       <th id="T_fdbaf_level0_row5" class="row_heading level0 row5" >model_year</th>
#       <td id="T_fdbaf_row5_col0" class="data row5 col0" >0.580541</td>
#       <td id="T_fdbaf_row5_col1" class="data row5 col1" >-0.345647</td>
#       <td id="T_fdbaf_row5_col2" class="data row5 col2" >-0.416361</td>
#       <td id="T_fdbaf_row5_col3" class="data row5 col3" >-0.309120</td>
#       <td id="T_fdbaf_row5_col4" class="data row5 col4" >0.290316</td>
#       <td id="T_fdbaf_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
mpg['lin_comb'] = 10 * mpg['cylinders'] - 0.3 * mpg['horsepower']
mpg.head(3)
# Out:
#     mpg  cylinders  horsepower  weight  acceleration  model_year  lin_comb
# 0  18.0          8       130.0    3504          12.0          70      41.0
# 1  15.0          8       165.0    3693          11.5          70      30.5
# 2  18.0          8       150.0    3436          11.0          70      35.0

# %%
# Matrix is not full-rank!
print(mpg.shape)
np.linalg.matrix_rank(mpg)
# Out:
# (392, 7)
# np.int64(6)

# %%
smf.ols(formula='weight ~ cylinders + horsepower + lin_comb', data=mpg).fit().params
# Out:
# Intercept     528.876711
# cylinders       3.375029
# horsepower     16.840512
# lin_comb       28.698140
# dtype: float64

# %%
# Now, change just a bit one single observation by 1% just on one feature
mpg.loc[0,'horsepower'] = mpg.loc[0,'horsepower']*1.01
smf.ols(formula='weight ~ cylinders + horsepower + lin_comb', data=mpg).fit().params
# Out:
# Intercept      524.838981
# cylinders     5954.582173
# horsepower    -161.691947
# lin_comb      -566.220542
# dtype: float64

# %%
# Statsmodels gives us a clear WARNING [2]
# Summary table also reads 'Covariance Type: nonrobust'
smf.ols(formula='weight ~ cylinders + horsepower + lin_comb', data=mpg).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 weight   R-squared:                       0.846
# Model:                            OLS   Adj. R-squared:                  0.845
# Method:                 Least Squares   F-statistic:                     712.9
# Date:                Tue, 28 Oct 2025   Prob (F-statistic):          1.99e-157
# Time:                        14:16:24   Log-Likelihood:                -2832.3
# No. Observations:                 392   AIC:                             5673.
# Df Residuals:                     388   BIC:                             5689.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    524.8390     56.865      9.230      0.000     413.038     636.640
# cylinders   5954.5822   4286.694      1.389      0.166   -2473.473    1.44e+04
# horsepower  -161.6919    128.597     -1.257      0.209    -414.526      91.142
# lin_comb    -566.2205    428.515     -1.321      0.187   -1408.722     276.281
# ==============================================================================
# Omnibus:                       12.222   Durbin-Watson:                   1.199
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               24.236
# Skew:                           0.069   Prob(JB):                     5.46e-06
# Kurtosis:                       4.210   Cond. No.                     2.91e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.91e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
mpg['lin_comb'] = mpg['lin_comb'] +  0.05 * np.random.rand(mpg.shape[0])
np.linalg.matrix_rank(mpg)
# Out:
# np.int64(7)

# %%
smf.ols(formula='weight ~ cylinders + horsepower + lin_comb', data=mpg).fit().params
# Out:
# Intercept      543.028388
# cylinders     7563.981263
# horsepower    -209.978602
# lin_comb      -727.148435
# dtype: float64

# %%
# Again, change just a bit one single observation in the dataset and check the OLS results
mpg.loc[0,'horsepower'] = mpg.loc[0,'horsepower']*0.8
smf.ols(formula='weight ~ cylinders + horsepower + lin_comb', data=mpg).fit().params
# Out:
# Intercept     524.875037
# cylinders     261.948804
# horsepower      9.088382
# lin_comb        3.030824
# dtype: float64

# %%
# Correlation matrix is not sufficient to detect soft or event strict multicollinearity
mpg.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_21275_row0_col0, #T_21275_row1_col1, #T_21275_row2_col2, #T_21275_row3_col3, #T_21275_row4_col4, #T_21275_row5_col5, #T_21275_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_21275_row0_col1, #T_21275_row0_col2, #T_21275_row0_col3, #T_21275_row0_col6, #T_21275_row2_col4, #T_21275_row2_col5, #T_21275_row3_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_21275_row0_col4 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_21275_row0_col5 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_21275_row1_col0, #T_21275_row2_col0 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_21275_row1_col2, #T_21275_row2_col1 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# #T_21275_row1_col3, #T_21275_row3_col1 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_21275_row1_col4 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_21275_row1_col5 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_21275_row1_col6 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_21275_row2_col3, #T_21275_row3_col2 {
#   background-color: #cf453c;
#   color: #f1f1f1;
# }
# #T_21275_row2_col6 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_21275_row3_col4 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_21275_row3_col5 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_21275_row3_col6 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_21275_row4_col0 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_21275_row4_col1 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_21275_row4_col2 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_21275_row4_col3, #T_21275_row5_col6 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_21275_row4_col5 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_21275_row4_col6 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_21275_row5_col0 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_21275_row5_col1 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_21275_row5_col2 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_21275_row5_col3 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_21275_row5_col4 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_21275_row6_col0, #T_21275_row6_col5 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_21275_row6_col1 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_21275_row6_col2 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_21275_row6_col3 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_21275_row6_col4 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# </style>
# <table id="T_21275">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_21275_level0_col0" class="col_heading level0 col0" >mpg</th>
#       <th id="T_21275_level0_col1" class="col_heading level0 col1" >cylinders</th>
#       <th id="T_21275_level0_col2" class="col_heading level0 col2" >horsepower</th>
#       <th id="T_21275_level0_col3" class="col_heading level0 col3" >weight</th>
#       <th id="T_21275_level0_col4" class="col_heading level0 col4" >acceleration</th>
#       <th id="T_21275_level0_col5" class="col_heading level0 col5" >model_year</th>
#       <th id="T_21275_level0_col6" class="col_heading level0 col6" >lin_comb</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_21275_level0_row0" class="row_heading level0 row0" >mpg</th>
#       <td id="T_21275_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_21275_row0_col1" class="data row0 col1" >-0.777618</td>
#       <td id="T_21275_row0_col2" class="data row0 col2" >-0.776518</td>
#       <td id="T_21275_row0_col3" class="data row0 col3" >-0.832244</td>
#       <td id="T_21275_row0_col4" class="data row0 col4" >0.423329</td>
#       <td id="T_21275_row0_col5" class="data row0 col5" >0.580541</td>
#       <td id="T_21275_row0_col6" class="data row0 col6" >-0.445165</td>
#     </tr>
#     <tr>
#       <th id="T_21275_level0_row1" class="row_heading level0 row1" >cylinders</th>
#       <td id="T_21275_row1_col0" class="data row1 col0" >-0.777618</td>
#       <td id="T_21275_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_21275_row1_col2" class="data row1 col2" >0.838737</td>
#       <td id="T_21275_row1_col3" class="data row1 col3" >0.897527</td>
#       <td id="T_21275_row1_col4" class="data row1 col4" >-0.504683</td>
#       <td id="T_21275_row1_col5" class="data row1 col5" >-0.345647</td>
#       <td id="T_21275_row1_col6" class="data row1 col6" >0.762598</td>
#     </tr>
#     <tr>
#       <th id="T_21275_level0_row2" class="row_heading level0 row2" >horsepower</th>
#       <td id="T_21275_row2_col0" class="data row2 col0" >-0.776518</td>
#       <td id="T_21275_row2_col1" class="data row2 col1" >0.838737</td>
#       <td id="T_21275_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_21275_row2_col3" class="data row2 col3" >0.862883</td>
#       <td id="T_21275_row2_col4" class="data row2 col4" >-0.685508</td>
#       <td id="T_21275_row2_col5" class="data row2 col5" >-0.411591</td>
#       <td id="T_21275_row2_col6" class="data row2 col6" >0.289442</td>
#     </tr>
#     <tr>
#       <th id="T_21275_level0_row3" class="row_heading level0 row3" >weight</th>
#       <td id="T_21275_row3_col0" class="data row3 col0" >-0.832244</td>
#       <td id="T_21275_row3_col1" class="data row3 col1" >0.897527</td>
#       <td id="T_21275_row3_col2" class="data row3 col2" >0.862883</td>
#       <td id="T_21275_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_21275_row3_col4" class="data row3 col4" >-0.416839</td>
#       <td id="T_21275_row3_col5" class="data row3 col5" >-0.309120</td>
#       <td id="T_21275_row3_col6" class="data row3 col6" >0.554605</td>
#     </tr>
#     <tr>
#       <th id="T_21275_level0_row4" class="row_heading level0 row4" >acceleration</th>
#       <td id="T_21275_row4_col0" class="data row4 col0" >0.423329</td>
#       <td id="T_21275_row4_col1" class="data row4 col1" >-0.504683</td>
#       <td id="T_21275_row4_col2" class="data row4 col2" >-0.685508</td>
#       <td id="T_21275_row4_col3" class="data row4 col3" >-0.416839</td>
#       <td id="T_21275_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_21275_row4_col5" class="data row4 col5" >0.290316</td>
#       <td id="T_21275_row4_col6" class="data row4 col6" >-0.067757</td>
#     </tr>
#     <tr>
#       <th id="T_21275_level0_row5" class="row_heading level0 row5" >model_year</th>
#       <td id="T_21275_row5_col0" class="data row5 col0" >0.580541</td>
#       <td id="T_21275_row5_col1" class="data row5 col1" >-0.345647</td>
#       <td id="T_21275_row5_col2" class="data row5 col2" >-0.411591</td>
#       <td id="T_21275_row5_col3" class="data row5 col3" >-0.309120</td>
#       <td id="T_21275_row5_col4" class="data row5 col4" >0.290316</td>
#       <td id="T_21275_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_21275_row5_col6" class="data row5 col6" >-0.113296</td>
#     </tr>
#     <tr>
#       <th id="T_21275_level0_row6" class="row_heading level0 row6" >lin_comb</th>
#       <td id="T_21275_row6_col0" class="data row6 col0" >-0.445165</td>
#       <td id="T_21275_row6_col1" class="data row6 col1" >0.762598</td>
#       <td id="T_21275_row6_col2" class="data row6 col2" >0.289442</td>
#       <td id="T_21275_row6_col3" class="data row6 col3" >0.554605</td>
#       <td id="T_21275_row6_col4" class="data row6 col4" >-0.067757</td>
#       <td id="T_21275_row6_col5" class="data row6 col5" >-0.113296</td>
#       <td id="T_21275_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
mpg_scaled = mpg.copy()

for feature in mpg_scaled.columns:
    mu = mpg[feature].mean()
    sigma = mpg[feature].std()
    mpg_scaled[feature] = mpg_scaled[feature].apply(lambda x: (x-mu)/sigma)

mpg_scaled
# Out:
#           mpg  cylinders  horsepower    weight  acceleration  model_year  \
# 0   -0.697747   1.482053   -0.506260  0.619748     -1.283618   -1.623241
# 1   -1.082115   1.482053    1.575947  0.842258     -1.464852   -1.623241
# 2   -0.697747   1.482053    1.186155  0.539692     -1.646086   -1.623241
# 3   -0.953992   1.482053    1.186155  0.536160     -1.283618   -1.623241
# 4   -0.825870   1.482053    0.926294  0.554997     -1.827320   -1.623241
# ..        ...        ...         ...       ...           ...         ...
# 393  0.455359  -0.862911   -0.476956 -0.220842      0.021267    1.634321
# 394  2.633448  -0.862911   -1.360484 -0.997859      3.283479    1.634321
# 395  1.095974  -0.862911   -0.528928 -0.803605     -1.428605    1.634321
# 396  0.583482  -0.862911   -0.658859 -0.415097      1.108671    1.634321
# 397  0.967851  -0.862911   -0.580901 -0.303253      1.398646    1.634321
#
#      lin_comb
# 0    1.836383
# 1    0.740643
# 2    1.208465
# 3    1.211946
# 4    1.525211
# ..        ...
# 393 -0.958006
# 394  0.108020
# 395 -0.892681
# 396 -0.734551
# 397 -0.829072
#
# [392 rows x 7 columns]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor as vif
# compute VIF factor for feature index 0
vif(mpg_scaled.values, 0)
# Out:
# np.float64(5.237391734461867)

# %%
df = pd.DataFrame()

df["features"] = mpg_scaled.columns

df["vif_index"] = [vif(mpg_scaled.values, i) for i in range(mpg_scaled.shape[1])]

round(df.sort_values(by="vif_index", ascending = False),2)
# Out:
#        features  vif_index
# 1     cylinders     665.12
# 2    horsepower     291.99
# 6      lin_comb     213.05
# 3        weight      11.25
# 0           mpg       5.24
# 4  acceleration       2.61
# 5    model_year       1.91
